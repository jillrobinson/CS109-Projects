# %% [markdown]
# # Brunching in Chicago
# Time Out Chicago (Amy Cavanaugh, 8th March 2016) published an [article](http://www.timeout.com/chicago/restaurants/20-best-brunch-spots-in-chicago) listing the 20 best brunch spots in Chicago. Yum! I want to see all the restaurant locations on a map and find the closest one to me that I haven't already visited. To do this, I needed to scrape the Time Out Chicago website for the restaurant names and locations, convert the addresses to lattitude and longitude co-ordinates for the calculation of distances and plotting on a map.
#
# > This project is inspired by Lecture 2 (about data scraping) of Harvard's CS109 Data Science course and is adapted from a number of the examples in the relevant lecture notes, including the example taken from Katharine Jarmul's talk about data scraping at PyCon2014. I'm using this project to practice the skills taught in these lectures.
#
# Let's start by importing all the libraries needed:

# %%
# All imports
import requests
import urllib2
import bs4
import socket
import re
import time
from pygeocoder import Geocoder
from math import radians, cos, sin, asin, sqrt
import folium
from collections import OrderedDict

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)

# %% [markdown]
# I am using `requests` and `BeautifulSoup` to scrape and parse the html from the website: http://www.timeout.com/chicago/restaurants/20-best-brunch-spots-in-chicago.

# %%
url = 'http://www.timeout.com/chicago/restaurants/20-best-brunch-spots-in-chicago'

# While urllib2 works, CS109 lab 2 suggests becoming acquainted with requests
# source = urllib2.urlopen(url).read()
# tree = bs4.BeautifulSoup(source, 'lxml')

req = requests.get(url)
page = req.text
tree = bs4.BeautifulSoup(page, 'html.parser')

print tree.prettify()
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="en"  class="ie ie8 "><![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <html class="" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8">
#    <meta content="IE=edge" http-equiv="X-UA-Compatible">
#     <script type="text/javascript">
#      window.NREUM||(NREUM={}),__nr_require=function(e,t,n){function r(n){if(!t[n]){var o=t[n]={exports:{}};e[n][0].call(o.exports,function(t){var o=e[n][1][t];return r(o||t)},o,o.exports)}return t[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({QJf3ax:[function(e,t){function n(){}function r(e){function t(e){return e&&e instanceof n?e:e?a(e,i,o):o()}function s(n,r,o){e&&e(n,r,o);for(var i=t(o),a=l(n),u=a.length,f=0;u>f;f++)a[f].apply(i,r);var s=c[w[n]];return s&&s.push([h,n,r,i]),i}function p(e,t){g[e]=l(e).concat(t)}function l(e){return g[e]||[]}function d(e){return f[e]=f[e]||r(s)}function v(e,t){u(e,function(e,n){t=t||"feature",w[n]=t,t in c||(c[t]=[])})}var g={},w={},h={on:p,emit:s,get:d,listeners:l,context:t,buffer:v};return h}function o(){return new n}var i="nr@context",a=e("gos"),u=e(1),c={},f={},s=t.exports=r();s.backlog=c},{1:12,gos:"7eSDFh"}],ee:[function(e,t){t.exports=e("QJf3ax")},{}],3:[function(e,t){function n(e,t){return function(){r(e,[(new Date).getTime()].concat(i(arguments)),null,t)}}var r=e("handle"),o=e(1),i=e(2);"undefined"==typeof window.newrelic&&(newrelic=NREUM);var a=["setPageViewName","addPageAction","setCustomAttribute","finished","addToTrace","inlineHit"],u=["addPageAction"],c="api-";o(a,function(e,t){newrelic[t]=n(c+t,"api")}),o(u,function(e,t){newrelic[t]=n(c+t)}),t.exports=newrelic,newrelic.noticeError=function(e){"string"==typeof e&&(e=new Error(e)),r("err",[e,(new Date).getTime()])}},{1:12,2:13,handle:"D5DuLP"}],gos:[function(e,t){t.exports=e("7eSDFh")},{}],"7eSDFh":[function(e,t){function n(e,t,n){if(r.call(e,t))return e[t];var o=n();if(Object.defineProperty&&Object.keys)try{return Object.defineProperty(e,t,{value:o,writable:!0,enumerable:!1}),o}catch(i){}return e[t]=o,o}var r=Object.prototype.hasOwnProperty;t.exports=n},{}],handle:[function(e,t){t.exports=e("D5DuLP")},{}],D5DuLP:[function(e,t){function n(e,t,n,o){r.buffer([e],o),r.emit(e,t,n)}var r=e("ee").get("handle");t.exports=n,n.ee=r},{ee:"QJf3ax"}],XL7HBI:[function(e,t){function n(e){var t=typeof e;return!e||"object"!==t&&"function"!==t?-1:e===window?0:i(e,o,function(){return r++})}var r=1,o="nr@id",i=e("gos");t.exports=n},{gos:"7eSDFh"}],id:[function(e,t){t.exports=e("XL7HBI")},{}],G9z0Bl:[function(e,t){function n(){if(!v++){var e=d.info=NREUM.info,t=f.getElementsByTagName("script")[0];if(e&&e.licenseKey&&e.applicationID&&t){u(p,function(t,n){e[t]||(e[t]=n)});var n="https"===s.split(":")[0]||e.sslForHttp;d.proto=n?"https://":"http://",a("mark",["onload",i()],null,"api");var r=f.createElement("script");r.src=d.proto+e.agent,t.parentNode.insertBefore(r,t)}}}function r(){"complete"===f.readyState&&o()}function o(){a("mark",["domContent",i()],null,"api")}function i(){return(new Date).getTime()}var a=e("handle"),u=e(1),c=window,f=c.document;NREUM.o={ST:setTimeout,XHR:c.XMLHttpRequest,REQ:c.Request,EV:c.Event,PR:c.Promise,MO:c.MutationObserver},e(2);var s=(""+location).split("?")[0],p={beacon:"bam.nr-data.net",errorBeacon:"bam.nr-data.net",agent:"js-agent.newrelic.com/nr-885.min.js"},l=window.XMLHttpRequest&&XMLHttpRequest.prototype&&XMLHttpRequest.prototype.addEventListener&&!/CriOS/.test(navigator.userAgent),d=t.exports={offset:i(),origin:s,features:{},xhrWrappable:l};f.addEventListener?(f.addEventListener("DOMContentLoaded",o,!1),c.addEventListener("load",n,!1)):(f.attachEvent("onreadystatechange",r),c.attachEvent("onload",n)),a("mark",["firstbyte",i()],null,"api");var v=0},{1:12,2:3,handle:"D5DuLP"}],loader:[function(e,t){t.exports=e("G9z0Bl")},{}],12:[function(e,t){function n(e,t){var n=[],o="",i=0;for(o in e)r.call(e,o)&&(n[i]=t(o,e[o]),i+=1);return n}var r=Object.prototype.hasOwnProperty;t.exports=n},{}],13:[function(e,t){function n(e,t,n){t||(t=0),"undefined"==typeof n&&(n=e?e.length:0);for(var r=-1,o=n-t||0,i=Array(0>o?0:o);++r<o;)i[r]=e[t+r];return i}t.exports=n},{}]},{},["G9z0Bl"]);
#     </script>
#     <meta content="width=device-width, initial-scale=1" name="viewport">
#      <meta content="v4" name="platform"/>
#      <meta content="en" name="language"/>
#      <meta content="en-US" name="locale"/>
#      <meta content="us-chicago" name="site"/>
#      <meta content='{"shopping_and_style_(category)":"category_1","health_and_beauty_(category)":"category_1","restaurants_(category)":"category_2","bars_and_pubs_(category)":"category_2","art_(category)":"category_3","theatre_(category)":"category_4","music_(category)":"category_5","nightlife_(category)":"category_5","clubs_(category)":"category_5","things_to_do_(category)":"category_6","attractions_(category)":"category_6","museums_(category)":"category_6","sport_and_fitness_(category)":"category_6","comedy_(category)":"category_7","film_genres":"category_8","cinemas_(category)":"category_8","film_(category)":"category_8","dance_(category)":"category_9","default":"category_10"}' name="category_mapping"/>
#      <meta content="/chicago" name="home_url"/>
#      <meta content="Chicago restaurants are always on top for brunch. These are the top 20 you should try right now for great Bloody Marys, eggs Benedict and more." name="description"/>
#      <link href="http://www.timeout.com/chicago/restaurants/20-best-brunch-spots-in-chicago" rel="canonical"/>
#      <link href="/favicon.ico" rel="icon" type="image/png"/>
#      <meta content="NOODP, NOYDIR" name="robots"/>
#      <meta content="https://media.timeout.com/images/103164109/image.jpg" property="og:image">
#       <meta content="Chicago's top 20 brunch restaurants" property="og:title">
#        <meta content="182128545196720" property="fb:app_id">
#         <meta content="http://www.timeout.com/chicago/restaurants/20-best-brunch-spots-in-chicago" property="og:url">
#          <meta content="Time Out Chicago" property="og:site_name">
#           <meta content="Chicago restaurants are always on top for brunch. These are the top 20 you should try right now for great Bloody Marys, eggs Benedict and more." property="og:description">
#            <meta content="article" property="og:type">
#             <meta content="summary_large_image" name="twitter:card">
#              <meta content="Chicago's top 20 brunch restaurants" name="twitter:title">
#               <meta content="If there’s one thing we take seriously here, it’s brunch. Here are the 20 best brunches to have right now." name="twitter:description">
#                <meta content="@timeoutchicago" name="twitter:site">
#                 <meta content="@timeoutchicago" name="twitter:creator">
#                  <meta content="https://media.timeout.com/images/103164109/image.jpg" property="twitter:image:src">
#                   <script type="text/javascript">
#                    (function () {
#     var tagjs = document.createElement("script");
#     var s = document.getElementsByTagName("script")[0];
#     tagjs.async = true;
#     tagjs.src = "https://s.btstatic.com/tag.js#site=5leRLIi";
#     s.parentNode.insertBefore(tagjs, s);
#   }());
#                   </script>
#                   <noscript>
#                    <iframe frameborder="0" height="1" marginheight="0" marginwidth="0" scrolling="no" src="https://s.thebrighttag.com/iframe?c=5leRLIi" width="1">
#                    </iframe>
#                   </noscript>
#                   <title>
#                    Chicago's top 20 brunch restaurants for Bloody Mary's, waffles and more
#                   </title>
#                   <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,300,700|Open+Sans+Condensed:300,700|Roboto+Condensed:400,700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css">
#                    <!--[if (gt IE 9)|!(IE)]><!-->
#                    <link href="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/css/timeout.css" rel="stylesheet">
#                     <!--<![endif]-->
#                     <!--[if lte IE 9]>
#         <link href="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/css/timeout_page_1.css" rel="stylesheet">
#         <link href="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/css/timeout_page_2.css" rel="stylesheet">
#         <![endif]-->
#                     <!-- HTML5 shim and Respond.js IE8 support of HTML5 elements and media queries -->
#                     <!--[if lte IE 9]>
#             <script src="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/js/lib/matchmedia.js"></script>
#         <![endif]-->
#                     <!--[if IE 9]>
#             <link href="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/css/crossbrowser/ie9.css" rel="stylesheet" />
#         <![endif]-->
#                     <!--[if IE 8]>
#             <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
#             <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
#             <link href="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/css/crossbrowser/ie8.css" rel="stylesheet" />
#         <![endif]-->
#                     <meta content="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/" name="asset_path"/>
#                     <script>
#                      (function() {
#         var gpt = document.createElement('script');
#         gpt.type = 'text/javascript';
#         gpt.async = true;
#         gpt.src = 'https://www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.appendChild(gpt);
#     })();
#                     </script>
#                     <meta data-module="adverts" data-params='{"host":"Time_Out_Chicago","network_code":5185,"zone":"restaurants","ad_pubs":{"page":"page","itemid":"page-21051","audience":"default"},"taggings":{"venue":["restaurants"],"kicker":["double-verify-alcohol-content"]}}'/>
#                     <script>
#                      (function() {
#         var rct = document.createElement('script');
#         rct.type = 'text/javascript';
#         rct.async = true;
#         rct.src = 'https://ads.rubiconproject.com/header/11092.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.appendChild(rct);
#     })();
#                     </script>
#                     <meta data-account="timeoutchicagonew,timeoutworldwide" data-content="{&quot;pageName&quot;:&quot;Feature : Chicago's top 20 brunch restaurants&quot;,&quot;prop3&quot;:&quot;chicago's top 20 brunch restaurants&quot;,&quot;prop4&quot;:&quot;content-page-21051&quot;,&quot;prop5&quot;:&quot;feature&quot;,&quot;hier1&quot;:&quot;chicago, feature&quot;,&quot;prop49&quot;:&quot;Chicago&quot;,&quot;prop53&quot;:&quot;en&quot;,&quot;prop54&quot;:&quot;Restaurants&quot;,&quot;prop55&quot;:null}" data-module="omniture" data-site-name="Chicago" data-track-manually="0"/>
#                     <script async="" src="https://native.sharethrough.com/assets/sfp.js" type="text/javascript">
#                     </script>
#                     <meta data-graffiti="/graffiti/v1" data-graffiti-site="us-chicago"/>
#                     <meta data-module="user" data-params='{
#                 "gigya_url": "https://cdns.gigya.com/JS/gigya.js?apikey=3_tQKJmyO5u50bQaNljqWymBh6uezUx-yvPK6kDyblgAUXK7V6Y-_aPghiLfHEUmNr&amp;lang=en",
#                 "token_url": "/chicago/en_US/user/token",
#                 "gigya_conf": {
#                     "lang": "en",
#                     "gigyaPlugins" : {
#                         "rememberSessionExpiration" : -2
#                     }
#                 },
#                 "welcome_url": "/chicago/en_US/user/email/welcome"
#             }'/>
#                     <meta data-maps-key="AIzaSyAu9752cHONt3pCfU_YTgirckesjlBcGHc"/>
#                     <script type="text/javascript">
#                      var digitalData = {
#     "pageInstanceID": "web-us-chicago.21051-prod",
#     "version": "1.0",
#     "page": {
#         "pageInfo": {
#             "pageID": 21051,
#             "pageName": "Chicago's top 20 brunch restaurants",
#             "version": 4,
#             "language": "en_US",
#             "country": "US",
#             "city": "Chicago",
#             "sysEnv": "prod",
#             "author": "",
#             "authorLevel": "",
#             "publishDate": null,
#             "pagination": "",
#             "destinationURL": "http:\/\/www.timeout.com\/chicago\/restaurants\/20-best-brunch-spots-in-chicago",
#             "referringURL": "http:\/\/l.facebook.com\/l.php?u=http%3A%2F%2Fwww.timeout.com%2Fchicago%2Frestaurants%2F20-best-brunch-spots-in-chicago&h=9AQFk_2JJ&enc=AZMzcXIZSnxZXl7-vig7yfSGYrUWLWnalYlPoBv3aKO3cN9Qs9in5OJoxWf0crc8-MJKzAdbhIb6uq0kSrtPJnyEJfl53UL8Z6yXZ5a_YYvKwVde4gdsthEieTLvVAo9axB4Ua_qC8JzfjaXE93_16MI5qDox3vJcXH7dzMf95M-Ww&s=1",
#             "pageSize": "",
#             "pageOrientation": "",
#             "pageViewType": "",
#             "hourOfDay": "13",
#             "dayOfWeek": "Wednesday"
#         },
#         "category": {
#             "primaryCategory": "restaurants (category)",
#             "subCategory1": null,
#             "pageTags": [
#                 "root",
#                 "categories",
#                 "restaurants (category)",
#                 "venue type",
#                 "restaurants & cafes (venues)",
#                 "zz brand specific tags",
#                 "kickers",
#                 "us kickers",
#                 "new york kickers",
#                 "doubleverifyalcoholcontent"
#             ],
#             "pageType": "feature"
#         },
#         "search": {
#             "onsiteSearchResults": "",
#             "onsiteSearchSortOrder": "",
#             "onsiteSearchDisplayedResults": "",
#             "parameter": [],
#             "items": []
#         },
#         "evfAttributes": {
#             "activeTab": "",
#             "area": "",
#             "contentLength": "",
#             "isPremium": false,
#             "specialOffer": "",
#             "editorialRating": "",
#             "userReviews": "",
#             "userRating": "",
#             "onlineBookingAvailable": "",
#             "roadblockDisplayed": false,
#             "criticsChoice": "",
#             "gallerySize": "",
#             "venue": {
#                 "venueSays": "",
#                 "venueAnnouncement": "",
#                 "moreVenues": "",
#                 "venuePriceRange": ""
#             }
#         }
#     }
# };
#                     </script>
#                    </link>
#                   </link>
#                  </meta>
#                 </meta>
#                </meta>
#               </meta>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </meta>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class=" feature-page en_US nojs" data-country="us">
#   <script>
#    document.body.className = document.body.className.replace('nojs','')
#   </script>
#   <div class="ad ad-skin" data-ad='{"type":"skin"}' data-component='{"componentInfo":{"componentID":"ad-skin-419282718","componentName":"skin"},"category":{"componentType":"advert"}}' id="ad-skin-419282718">
#    <noscript>
#     <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-skin;page=page;itemid=page-21051;audience=default;tile=5;sz=1x1;ord=1891764251;venue=restaurants;kicker=double-verify-alcohol-content;?">
#      <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-skin;page=page;itemid=page-21051;audience=default;tile=5;sz=1x1;ord=1891764251;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#     </a>
#    </noscript>
#   </div>
#   <div class="ad ad-inline" data-ad='{"type":"inline"}' data-component='{"componentInfo":{"componentID":"ad-inline-423965545","componentName":"inline"},"category":{"componentType":"advert"}}' id="ad-inline-423965545">
#    <noscript>
#     <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-inline;page=page;itemid=page-21051;audience=default;tile=5;sz=1x1;ord=1647772194;venue=restaurants;kicker=double-verify-alcohol-content;?">
#      <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-inline;page=page;itemid=page-21051;audience=default;tile=5;sz=1x1;ord=1647772194;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#     </a>
#    </noscript>
#   </div>
#   <div id="main-container">
#    <section class="sr-only">
#     <a aria-hidden="true" href="#content">
#      Go to the content
#     </a>
#     <a aria-hidden="true" href="#site-footer">
#      Go to the footer
#     </a>
#    </section>
#    <header class="header " id="header" role="banner">
#     <div class="sticky-placeholder">
#      <div class="sticky fixed">
#       <div class="masthead" id="masthead">
#        <div class="container">
#         <div class="branding">
#          <div class="logos__desktop">
#           <a class="timeout-logo" data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"logo"}}' href="/chicago" title="Time Out Chicago">
#            Time Out Chicago
#           </a>
#           <div class="city-picker city-picker--desktop" data-labels='{"popular_cities":"Popular cities","browse_all":"Browse all cities","change_city":"Change city"}' data-languages="[]" data-location="Chicago" data-mobile="" data-module="city-picker" data-popular-cities='[{"cityName":"London","url":"\/london","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - london\"}}"},{"cityName":"New York","url":"\/newyork","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - new york\"}}"},{"cityName":"Paris","url":"\/paris","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - paris\"}}"},{"cityName":"Chicago","url":"\/chicago","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - chicago\"}}"},{"cityName":"Los Angeles","url":"\/los-angeles","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - los angeles\"}}"}]'>
#           </div>
#          </div>
#          <div class="logos__mobile">
#           <a class="timeout-logo" data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"logo mobile"}}' href="/chicago" title="Time Out Chicago">
#            Time Out Chicago
#           </a>
#          </div>
#         </div>
#         <div class="mobile-menu">
#          <div class="nav-top-item nav-utils__item">
#           <nav class="drawer-menu drawer-menu__dir-left js-mobile-menu" data-custom-labels="[]" data-module="drawer" data-uid="935457154">
#            <input class="drawer-menu__toggle" data-uid="935457154" id="drawer-menu__toggle_935457154" type="checkbox">
#             <div class="drawer-menu__content">
#              <label class="drawer-menu__close_button icon_close" for="drawer-menu__toggle_935457154">
#               <span>
#                Close
#               </span>
#              </label>
#              <div class="drawer-menu__include">
#               <nav class="navmenu" id="mobile-nav" role="navigation">
#                <ul class="nav">
#                 <li>
#                  <div class="city-picker city-picker--mobile" data-labels='{"popular_cities":"Popular cities","browse_all":"Browse all cities","change_city":"Change city"}' data-languages="[]" data-location="Chicago" data-mobile="1" data-module="city-picker" data-popular-cities='[{"cityName":"London","url":"\/london","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - london\"}}"},{"cityName":"New York","url":"\/newyork","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - new york\"}}"},{"cityName":"Paris","url":"\/paris","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - paris\"}}"},{"cityName":"Chicago","url":"\/chicago","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - chicago\"}}"},{"cityName":"Los Angeles","url":"\/los-angeles","data_tracking":"{\"eventInfo\":{\"eventName\":\"navigation click\",\"eventAction\":\"navigation_clicks\",\"type\":\"custom\"},\"attributes\":{\"linkTitle\":\"site name - los angeles\"}}"}]'>
#                  </div>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"things to do menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"things to do"}}' href="/chicago/things-to-do" target="_self" title="Things To Do">
#                   Things To Do
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"restaurants menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"restaurants"}}' href="/chicago/restaurants" target="_self" title="Restaurants">
#                   Restaurants
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"bars menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"bars"}}' href="/chicago/bars" target="_self" title="Bars">
#                   Bars
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"movies menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"movies"}}' href="/chicago/movies" target="_self" title="Movies">
#                   Movies
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"theater menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"theater"}}' href="/chicago/theater" target="_self" title="Theater">
#                   Theater
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"music menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"music"}}' href="/chicago/music-nightlife" target="_self" title="Music">
#                   Music
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"shopping menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"shopping"}}' href="/chicago/shopping" target="_self" title="Shopping">
#                   Shopping
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"attractions menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"attractions"}}' href="/chicago/attractions" target="_self" title="Attractions">
#                   Attractions
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"blog menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"blog"}}' href="/chicago/blog" target="_self" title="Blog">
#                   Blog
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"kids menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"kids"}}' href="/chicago/kids" target="_self" title="Kids">
#                   Kids
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"travel menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"travel"}}' href="/chicago/travel" target="_self" title="Travel">
#                   Travel
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"events &amp; festivals menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"events &amp; festivals"}}' href="/chicago/things-to-do/events-festivals" target="_self" title="Events &amp; Festivals">
#                   Events &amp; Festivals
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"museums menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"museums"}}' href="/chicago/museums" target="_self" title="Museums">
#                   Museums
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"city guide menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"city guide"}}' href="/chicago/city-guide" target="_self" title="City Guide">
#                   City Guide
#                  </a>
#                 </li>
#                 <li>
#                  <a class="mobile-nav_item " data-track-click='{"pev2":"neighborhoods menu drawer"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"neighborhoods"}}' href="/chicago/neighborhoods" target="_self" title="Neighborhoods">
#                   Neighborhoods
#                  </a>
#                 </li>
#                </ul>
#               </nav>
#              </div>
#             </div>
#             <label class="drawer-menu__label mobile-menu__drawer icon_burger " data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"mobile menu drawer"}}' for="drawer-menu__toggle_935457154">
#             </label>
#            </input>
#           </nav>
#          </div>
#         </div>
#         <div class="nav-utils">
#          <div class="nav-top-item nav-utils__item--desktop-last">
#           <nav class="drawer-menu drawer-menu__dir-right " data-custom-labels='["user_drawer__label"]' data-module="drawer" data-uid="787874860">
#            <input class="drawer-menu__toggle" data-uid="787874860" id="drawer-menu__toggle_787874860" type="checkbox">
#             <div class="drawer-menu__content">
#              <label class="drawer-menu__close_button icon_close" for="drawer-menu__toggle_787874860">
#               <span>
#                Close
#               </span>
#              </label>
#              <div class="drawer-menu__include">
#               <div class="user__panel" data-action="log-register" data-module="gigya" data-params='{
#         "screens": {
#             "screenSet":   "gigya-screens",
#             "containerID": "gigya-container",
#             "startScreen": "login-screen"
#         }
#     }'>
#                <nav class="gigya-screens__nav">
#                 <div class="gigya-screens__nav--logged-in">
#                  <a class="icon_cta--large icon_cta--centre" href="/chicago/my">
#                   <span class="icon_cta__icon icon_home_filled">
#                   </span>
#                   <span class="icon_cta__text">
#                    My Time Out
#                   </span>
#                  </a>
#                  <a class="icon_cta--large icon_cta--centre" href="/chicago/my#/favourites">
#                   <span class="icon_cta__icon icon_heart_filled">
#                   </span>
#                   <span class="icon_cta__text">
#                    Things I love
#                   </span>
#                  </a>
#                  <a class="icon_cta--large icon_cta--centre" href="/chicago/my#/lists">
#                   <span class="icon_cta__icon icon_listview">
#                   </span>
#                   <span class="icon_cta__text">
#                    My lists
#                   </span>
#                  </a>
#                  <a class="icon_cta--large icon_cta--light icon_cta--centre" href="/chicago/user/myAccount">
#                   <span class="icon_cta__text">
#                    My Account
#                   </span>
#                  </a>
#                  <button class="icon_cta--large icon_cta--light icon_cta--centre" data-action="logOut" data-module="gigya" id="user-logout">
#                   <span class="icon_cta__text">
#                    Sign out
#                   </span>
#                  </button>
#                 </div>
#                 <div class="gigya-screens__nav--log-register">
#                  <a class="gigya-screens__nav_item gigya-active-button" data-action="switchscreen" data-module="gigya" data-params="login-screen" href="#">
#                   <span>
#                    Sign in
#                   </span>
#                  </a>
#                  <a class="gigya-screens__nav_item" data-action="switchscreen" data-module="gigya" data-params="create_account_screen" href="#">
#                   <span>
#                    Create account
#                   </span>
#                  </a>
#                 </div>
#                </nav>
#                <div id="gigya-container">
#                </div>
#                <div class="gigya-screen-set" data-on-pending-registration-screen="confirm_account_screen" id="gigya-screens">
#                 <div class="gigya-screen" id="login-screen">
#                  <h3>
#                   Sign in
#                  </h3>
#                  <div class="gigya-screens_social_login_prompt">
#                   <p class="gigya-screens__info">
#                    With your social account:
#                   </p>
#                   <div class="gigya-social-login" id="gigya-social-login_1795694536" style="overflow:hidden;height:40px;min-height:40px;">
#                    <param name="width" value="250">
#                     <param name="height" value="35">
#                      <param name="enabledProviders" value="Facebook,Googleplus,Twitter">
#                       <param name="facebookExtraPermissions" value="email,user_events,user_likes,user_friends,user_location">
#                       </param>
#                       <param name="showWhatsThis" value="false">
#                        <param name="showTermsLink" value="false">
#                         <param name="hideGigyaLink" value="true">
#                         </param>
#                        </param>
#                       </param>
#                      </param>
#                     </param>
#                    </param>
#                   </div>
#                   <div class="gigya-error-msg error-msg alert alert-danger" data-bound-to="gigya-social-login_1795694536">
#                   </div>
#                  </div>
#                  <p class="gigya-screens__info">
#                   Or with your email:
#                  </p>
#                  <form class="gigya-login-form" method="POST" role="form">
#                   <div class="gigya-composite-control gigya-composite-control-textbox">
#                    <label for="loginID">
#                     Email:
#                    </label>
#                    <input class="gigya-input-text" name="loginID" tabindex="3" type="text" value="">
#                     <span class="gigya-error-msg" data-bound-to="loginID">
#                     </span>
#                    </input>
#                   </div>
#                   <div class="gigya-composite-control gigya-composite-control-password">
#                    <label for="password">
#                     Password:
#                    </label>
#                    <input class="gigya-input-password" name="password" tabindex="3" type="password">
#                     <span class="gigya-error-msg" data-bound-to="password">
#                     </span>
#                    </input>
#                   </div>
#                   <label for="remember">
#                    Remember me
#                   </label>
#                   <input id="remember" name="remember" type="checkbox">
#                    <div class="gigya-error-msg error-msg alert alert-danger" data-bound-to="gigya-login-form">
#                    </div>
#                    <a class="gigya-forgotten_password" href="/chicago/user/forgotPassword">
#                     Forgotten your password?
#                    </a>
#                    <button class="gigya-input-submit" tabindex="3" type="submit">
#                     Sign in
#                    </button>
#                   </input>
#                  </form>
#                 </div>
#                 <div class="gigya-screen" id="create_account_screen">
#                  <h3>
#                   You can create a Time Out account in two ways...
#                  </h3>
#                  <div class="gigya-screens_social_login_prompt">
#                   <p class="gigya-screens__info">
#                    With a few clicks using your favourite social network
#                   </p>
#                   <div class="gigya-social-login" id="gigya-social-login_318492417" style="overflow:hidden;height:40px;min-height:40px;">
#                    <param name="width" value="250">
#                     <param name="height" value="35">
#                      <param name="enabledProviders" value="Facebook,Googleplus,Twitter">
#                       <param name="facebookExtraPermissions" value="email,user_events,user_likes,user_friends,user_location">
#                       </param>
#                       <param name="showWhatsThis" value="false">
#                        <param name="showTermsLink" value="false">
#                         <param name="hideGigyaLink" value="true">
#                         </param>
#                        </param>
#                       </param>
#                      </param>
#                     </param>
#                    </param>
#                   </div>
#                   <div class="gigya-error-msg error-msg alert alert-danger" data-bound-to="gigya-social-login_318492417">
#                   </div>
#                  </div>
#                  <p class="gigya-screens__info">
#                   Or by entering your details below
#                  </p>
#                  <form class="gigya-register-form" id="create_account_form" method="POST" role="form">
#                   <label for="email">
#                    Email
#                   </label>
#                   <input name="email" required="" type="email"/>
#                   <span class="gigya-error-msg" data-bound-to="email">
#                   </span>
#                   <label for="profile.firstName">
#                    First Name
#                   </label>
#                   <input name="profile.firstName" type="text"/>
#                   <span class="gigya-error-msg" data-bound-to="profile.firstName">
#                   </span>
#                   <label for="profile.lastName">
#                    Last Name
#                   </label>
#                   <input name="profile.lastName" type="text"/>
#                   <span class="gigya-error-msg" data-bound-to="profile.lastName">
#                   </span>
#                   <label for="password">
#                    Create password
#                   </label>
#                   <input name="password" type="password"/>
#                   <span class="gigya-error-msg" data-bound-to="password">
#                   </span>
#                   <label for="passwordRetype">
#                    Repeat new password
#                   </label>
#                   <input name="passwordRetype" type="password"/>
#                   <span class="gigya-error-msg" data-bound-to="passwordRetype">
#                   </span>
#                   <input name="data.hasPassword" type="hidden" value="true"/>
#                   <input class="hidden" name="data.displayName" type="text"/>
#                   <fieldset class="gigya-screens__terms">
#                    <div class="checkbox">
#                     <input id="data.terms" name="data.terms" type="checkbox">
#                      <label class="gigya-screens__terms_label" for="data.terms">
#                       I accept Time Out's
#                       <a href="http://www.timeout.com/chicago/terms-conditions" target="_blank">
#                        terms of use
#                       </a>
#                       , including opt-in to newsletters.
#                      </label>
#                      <span class="gigya-error-msg error-msg" data-bound-to="data.terms">
#                      </span>
#                     </input>
#                    </div>
#                   </fieldset>
#                   <span class="gigya-error-msg" data-bound-to="create_account_form">
#                   </span>
#                   <button class="gigya-input-submit" type="submit">
#                    Create account
#                   </button>
#                  </form>
#                 </div>
#                 <div class="gigya-screen" id="confirm_account_screen">
#                  <h3 class="gigya-screens__subtitle">
#                   Welcome,
#                   <span data-action="confirm_account_screen" data-module="gigyascreens" data-params="profile.firstName">
#                   </span>
#                   !
#                  </h3>
#                  <div class="gigya-profile-photo">
#                  </div>
#                  <p class="gigya-screens__info">
#                   You have successfully connected your
#                   <span class="gigya-login-provider">
#                   </span>
#                   account to Time Out. You may sign in with this account in future.
#                  </p>
#                  <p class="gigya-screens__info">
#                   Please confirm your account details
#                  </p>
#                  <form class="gigya-profile-form" id="confirm_account_form" method="POST">
#                   <div class="form-group">
#                    <label for="email">
#                     Email
#                    </label>
#                    <input class="form-control" name="email" required="" type="email"/>
#                    <span class="gigya-error-msg error-msg" data-bound-to="email">
#                    </span>
#                    <span class="gigya-error-msg error-msg" data-bound-to="loginID">
#                    </span>
#                   </div>
#                   <div class="form-group">
#                    <label for="email">
#                     First Name
#                    </label>
#                    <input class="form-control" name="profile.firstName" type="text"/>
#                    <span class="gigya-error-msg error-msg" data-bound-to="profile.firstName">
#                    </span>
#                   </div>
#                   <div class="form-group">
#                    <label class="" for="email">
#                     Last Name
#                    </label>
#                    <input class="form-control" name="profile.lastName" type="text"/>
#                    <span class="gigya-error-msg error-msg" data-bound-to="profile.lastName">
#                    </span>
#                   </div>
#                   <fieldset class="gigya-screens__terms">
#                    <div class="checkbox">
#                     <input id="data.terms" name="data.terms" type="checkbox">
#                      <label class="gigya-screens__terms_label" for="data.terms">
#                       I accept Time Out's
#                       <a href="http://www.timeout.com/chicago/terms-conditions" target="_blank">
#                        terms of use
#                       </a>
#                       , including opt-in to newsletters.
#                      </label>
#                      <span class="gigya-error-msg error-msg" data-bound-to="data.terms">
#                      </span>
#                     </input>
#                    </div>
#                   </fieldset>
#                   <span class="gigya-error-msg error-msg" data-bound-to="confirm_account_form">
#                   </span>
#                   <input class="hidden" name="data.displayName" type="text"/>
#                   <button class="gigya-input-submit" type="submit">
#                    Sign up
#                   </button>
#                  </form>
#                 </div>
#                </div>
#                <div class="error-handler" data-module="error-handler" data-params="{
#             &quot;subscribe&quot;: {
#                 &quot;user.auth.error.generic&quot; : &quot;We couldn't log you in! Please try again later.&quot;
#             }
#         }">
#                </div>
#               </div>
#              </div>
#             </div>
#             <label class="drawer-menu__label drawer-menu__label--has-custom" data-track-click='{"pev2":"your time out","eVar59":"D=pev2"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"sign in drawer"}}' for="drawer-menu__toggle_787874860">
#              <span class="user_greeting user_greeting--none" data-module="user_element">
#               <span class="user_greeting__label user_greeting__label--logged_in" data-selector="user_drawer__label">
#                <i>
#                 My Account
#                </i>
#               </span>
#               <span class="user_greeting__image" data-selector="user_drawer__label">
#                <img/>
#               </span>
#               <span class="user_greeting__label user_greeting__label--anonymous">
#                <i>
#                 <strong class="user_greeting__label-inner-button" data-action="switch_gigya_screen_external" data-params="login-screen" data-selector="user_drawer__label">
#                  Sign in
#                 </strong>
#                 <span class="">
#                  or
#                 </span>
#                 <strong class="user_greeting__label-inner-button" data-action="switch_gigya_screen_external" data-params="create_account_screen" data-selector="user_drawer__label">
#                  Create account
#                 </strong>
#                </i>
#               </span>
#              </span>
#             </label>
#            </input>
#           </nav>
#          </div>
#          <div class="nav-top-item nav-utils__item--mobile">
#           <a class="search-trigger" data-track-click='{"pev2":"search header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"search"}}' href="/chicago/search">
#            <span>
#             <i>
#              Search
#             </i>
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <nav class="navbar" data-module="navigation" id="primary-nav" role="navigation">
#        <div class="container">
#         <ul class="nav nav--hidden">
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"things to do header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"things to do"}}' href="/chicago/things-to-do" target="_self" title="Things To Do">
#            Things To Do
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"restaurants header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"restaurants"}}' href="/chicago/restaurants" target="_self" title="Restaurants">
#            Restaurants
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"bars header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"bars"}}' href="/chicago/bars" target="_self" title="Bars">
#            Bars
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"movies header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"movies"}}' href="/chicago/movies" target="_self" title="Movies">
#            Movies
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"theater header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"theater"}}' href="/chicago/theater" target="_self" title="Theater">
#            Theater
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"music header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"music"}}' href="/chicago/music-nightlife" target="_self" title="Music">
#            Music
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"shopping header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"shopping"}}' href="/chicago/shopping" target="_self" title="Shopping">
#            Shopping
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"attractions header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"attractions"}}' href="/chicago/attractions" target="_self" title="Attractions">
#            Attractions
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"blog header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"blog"}}' href="/chicago/blog" target="_self" title="Blog">
#            Blog
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"kids header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"kids"}}' href="/chicago/kids" target="_self" title="Kids">
#            Kids
#           </a>
#          </li>
#          <li class="nav-top-item ">
#           <a data-track-click='{"pev2":"travel header"}' data-tracking='{"eventInfo":{"eventName":"navigation click","eventAction":"navigation_clicks","type":"custom"},"attributes":{"linkTitle":"travel"}}' href="/chicago/travel" target="_self" title="Travel">
#            Travel
#           </a>
#          </li>
#          <li class="nav-top-item ">
# ...
#        <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-mpu;page=page;itemid=page-21051;audience=default;tile=2;sz=300x250;ord=41048831;venue=restaurants;kicker=double-verify-alcohol-content;?">
#         <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-mpu;page=page;itemid=page-21051;audience=default;tile=2;sz=300x250;ord=41048831;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#        </a>
#       </noscript>
#      </div>
#      <div class="promo_list_wrapper">
#       <h3>
#        You might also like
#       </h3>
#       <section aria-live="polite" class="tabs tabs_widget inverted_theme" role="region">
#        <input checked="checked" class="tab__input" data-tab-input="1" id="tabs_5031533261" name="radio-set-rhr" type="radio"/>
#        <ul class="promo_list">
#         <li class="promo_list__item">
#          <a href="/chicago/restaurants/custom-house-township-stop-its-tea-time-brunch-reviews" title="Custom House, Township, “Stop! It’s tea time!” | Brunch reviews">
#           <img alt="" class="promo_list__item__thumb" src="https://media.timeout.com/images/101176445/60/45/image.jpg"/>
#           <span class="promo_list__item__title">
#            Custom House, Township, “Stop! It’s tea time!” | Brunch reviews
#           </span>
#          </a>
#         </li>
#         <li class="promo_list__item">
#          <a href="/chicago/restaurants/8-chicago-restaurants-decorated-for-the-holiday-season" title="8 Chicago restaurants decorated for the holiday season">
#           <img alt="" class="promo_list__item__thumb" src="https://media.timeout.com/images/101449945/60/45/image.jpg"/>
#           <span class="promo_list__item__title">
#            8 Chicago restaurants decorated for the holiday season
#           </span>
#          </a>
#         </li>
#         <li class="promo_list__item">
#          <a href="/chicago/comedy/tbs-just-for-laughs-festival-2012-our-picks" title="TBS Just for Laughs Festival 2012 | Our picks">
#           <img alt="" class="promo_list__item__thumb" src="https://media.timeout.com/images/101423323/60/45/image.jpg"/>
#           <span class="promo_list__item__title">
#            TBS Just for Laughs Festival 2012 | Our picks
#           </span>
#          </a>
#         </li>
#         <li class="promo_list__item">
#          <a href="/chicago/gay-lesbian/the-eagle-has-not-yet-landed" title="The Eagle has not yet landed">
#           <img alt="" class="promo_list__item__thumb" src="https://media.timeout.com/images/100959191/60/45/image.jpg"/>
#           <span class="promo_list__item__title">
#            The Eagle has not yet landed
#           </span>
#          </a>
#         </li>
#         <li class="promo_list__item">
#          <a href="/chicago/food-drink/city-tavern-tasting-notes" title="City Tavern | Tasting notes">
#           <img alt="" class="promo_list__item__thumb" src="https://media.timeout.com/images/100883361/60/45/image.jpg"/>
#           <span class="promo_list__item__title">
#            City Tavern | Tasting notes
#           </span>
#          </a>
#         </li>
#        </ul>
#       </section>
#      </div>
#      <div class="ad module ad--bottommpu" data-ad='{"type":"bottommpu"}' data-component='{"componentInfo":{"componentID":"ad-bottom-mpu-558788523","componentName":"bottommpu"},"category":{"componentType":"advert"}}' id="ad-bottom-mpu-558788523">
#       <noscript>
#        <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-bottom-mpu;page=page;itemid=page-21051;audience=default;tile=3;sz=300x250,300x600;ord=1679643331;venue=restaurants;kicker=double-verify-alcohol-content;?">
#         <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-bottom-mpu;page=page;itemid=page-21051;audience=default;tile=3;sz=300x250,300x600;ord=1679643331;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#        </a>
#       </noscript>
#      </div>
#     </aside>
#     <div class="ad ad-mobile-background" data-ad='{"type":"mobile_background"}' data-component='{"componentInfo":{"componentID":"ad-mobile-background-15168528","componentName":"mobile_background"},"category":{"componentType":"advert"}}' id="ad-mobile-background-15168528">
#      <noscript>
#       <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-mobile-background;page=page;itemid=page-21051;audience=default;tile=9;sz=300, 50;ord=603677181;venue=restaurants;kicker=double-verify-alcohol-content;?">
#        <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-mobile-background;page=page;itemid=page-21051;audience=default;tile=9;sz=300, 50;ord=603677181;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#       </a>
#      </noscript>
#     </div>
#     <div class="ad ad-mobile-cta" data-ad='{"type":"mobile_cta"}' data-component='{"componentInfo":{"componentID":"ad-mobile-cta-1020567288","componentName":"mobile_cta"},"category":{"componentType":"advert"}}' id="ad-mobile-cta-1020567288">
#      <noscript>
#       <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-mobile-cta;page=page;itemid=page-21051;audience=default;tile=10;sz=300, 25;ord=414577629;venue=restaurants;kicker=double-verify-alcohol-content;?">
#        <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-mobile-cta;page=page;itemid=page-21051;audience=default;tile=10;sz=300, 25;ord=414577629;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#       </a>
#      </noscript>
#     </div>
#    </main>
#    <footer class="site-footer">
#     <nav aria-label="Bottom navigation" class="site-footer__nav" id="footer-nav" role="navigation">
#      <div class="container">
#       <a class="site-footer__top-link" href="javascript:scrollTo(0,0)">
#        Top
#       </a>
#       <div class="row">
#        <!-- footer columns as defined in config -->
#        <div class="footer-tab">
#         <input class="footer-tab__toggle" id="footer-tab__toggle_0" type="checkbox">
#          <h4>
#           <label for="footer-tab__toggle_0">
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"About us"}}' href="http://www.timeout.com/about/" target="_self" title="About us">
#             About us
#            </a>
#           </label>
#          </h4>
#          <ul>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Work for Time Out"}}' href="http://www.timeout.com/about/time-out-group/work-for-time-out" target="_self" title="Work for Time Out">
#             Work for Time Out
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Privacy policy"}}' href="http://www.timeout.com/chicago/privacy-policy" target="_self" title="Privacy policy">
#             Privacy policy
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Website terms of use"}}' href="http://www.timeout.com/chicago/terms-conditions" target="_self" title="Website terms of use">
#             Website terms of use
#            </a>
#           </li>
#          </ul>
#         </input>
#        </div>
#        <div class="footer-tab">
#         <input class="footer-tab__toggle" id="footer-tab__toggle_1" type="checkbox">
#          <h4>
#           <label for="footer-tab__toggle_1">
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Contact us"}}' href="http://www.timeout.com/chicago/contact" target="_self" title="Contact us">
#             Contact us
#            </a>
#           </label>
#          </h4>
#          <ul>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Get listed"}}' href="http://www.timeout.com/chicago/get-listed" target="_self" title="Get listed">
#             Get listed
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Advertising"}}' href="http://clientcenter.timeout.com/" target="_self" title="Advertising">
#             Advertising
#            </a>
#           </li>
#          </ul>
#         </input>
#        </div>
#        <div class="footer-tab">
#         <input class="footer-tab__toggle" id="footer-tab__toggle_2" type="checkbox">
#          <h4>
#           <label for="footer-tab__toggle_2">
#            Time Out products
#           </label>
#          </h4>
#          <ul>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Mobile apps"}}' href="http://www.timeout.com/chicago/time-out-apps" target="_blank" title="Mobile apps">
#             Mobile apps
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Time Out Shop"}}' href="http://shop.timeout.com" target="_blank" title="Time Out Shop">
#             Time Out Shop
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Time Out Guides"}}' href="http://shop.timeout.com/" target="_blank" title="Time Out Guides">
#             Time Out Guides
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Time Out Travel"}}' href="http://www.timeout.com/travel" target="_blank" title="Time Out Travel">
#             Time Out Travel
#            </a>
#           </li>
#           <li>
#            <a data-tracking='{"eventInfo":{"eventName":"footer-clicks","eventAction":"footer_clicks","type":"custom"},"attributes":{"link":"Time Out worldwide"}}' href="http://www.timeout.com" target="_blank" title="Time Out worldwide">
#             Time Out worldwide
#            </a>
#           </li>
#          </ul>
#         </input>
#        </div>
#        <div class="footer-tab social-links social-links--footer">
#         <h4>
#          Follow us
#         </h4>
#         <span class="social-links__link-wrapper">
#          <a class="social-link icon_facebook" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"facebook"}}' href="http://www.facebook.com/timeoutchicago" target="_blank" title="Facebook">
#           <span>
#            Facebook
#           </span>
#          </a>
#          <a class="social-link icon_twitter" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"twitter"}}' href="http://www.twitter.com/timeoutchicago" target="_blank" title="Twitter">
#           <span>
#            Twitter
#           </span>
#          </a>
#          <a class="social-link icon_instagram" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"instagram"}}' href="http://instagram.com/timeoutchicago" target="_blank" title="Instagram">
#           <span>
#            Instagram
#           </span>
#          </a>
#          <a class="social-link icon_pinterest" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"pinterest"}}' href="http://pinterest.com/timeoutchicago" target="_blank" title="Pinterest">
#           <span>
#            Pinterest
#           </span>
#          </a>
#          <a class="social-link icon_googleplus" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"googleplus"}}' href="http://plus.google.com/+timeoutchicago" target="_blank" title="Googleplus">
#           <span>
#            Googleplus
#           </span>
#          </a>
#          <a class="social-link icon_spotify" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"spotify"}}' href="http://open.spotify.com/user/timeoutchicago" target="_blank" title="Spotify">
#           <span>
#            Spotify
#           </span>
#          </a>
#          <a class="social-link icon_foursquare" data-tracking='{"eventInfo":{"eventName":"social","eventAction":"social","type":"custom"},"attributes":{"action":"follow","socialNetwork":"foursquare"}}' href="http://foursquare.com/timeoutchicago" target="_blank" title="Foursquare">
#           <span>
#            Foursquare
#           </span>
#          </a>
#         </span>
#        </div>
#       </div>
#      </div>
#     </nav>
#     <div class="site-footer__utilities">
#      <div class="container">
#       <a class="timeout-logo" href="/chicago" title="Time Out Chicago">
#        Time Out Chicago
#       </a>
#       <a class="site-map" href="http://www.timeout.com/chicago/sitemap">
#        Site map
#       </a>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <div class="ad " data-ad='{"type":"oop"}' data-component='{"componentInfo":{"componentID":"ad-interstitial-oop-1688131131","componentName":"oop"},"category":{"componentType":"advert"}}' id="ad-interstitial-oop-1688131131">
#    <noscript>
#     <a href="http://ad.doubleclick.net/5185/jump/Time_Out_Chicago/restaurants;type=ad-interstitial-oop;page=page;itemid=page-21051;audience=default;tile=1;sz=300x250;ord=1410899964;venue=restaurants;kicker=double-verify-alcohol-content;?">
#      <img src="http://ad.doubleclick.net/5185/ad/Time_Out_Chicago/restaurants;type=ad-interstitial-oop;page=page;itemid=page-21051;audience=default;tile=1;sz=300x250;ord=1410899964;venue=restaurants;kicker=double-verify-alcohol-content;?"/>
#     </a>
#    </noscript>
#   </div>
#   <noscript id="omnitureNoscript">
#    <img height="1" src="https://smetrics.timeout.com/b/ss/timeoutchicagonew,timeoutworldwide/1/H.23.8--NS/0?pageName=TO+%3A+No+Script" width="1"/>
#    }
#   </noscript>
#   <script data-main="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/js/main.js" src="//dist.timeout.com/dist/721e11bc14a5ac9ba0045bffdc18511fcc1a2aaa/js/main.js">
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"url":"http://www.timeout.com/chicago/restaurants/longman-eagle"},{"@type":"ListItem","position":2,"url":"http://www.timeout.com/chicago/restaurants/au-cheval"},{"@type":"ListItem","position":3,"url":"http://www.timeout.com/chicago/restaurants/cherry-circle-room"},{"@type":"ListItem","position":4,"url":"http://www.timeout.com/chicago/restaurants/bohemian-house"},{"@type":"ListItem","position":5,"url":"http://www.timeout.com/chicago/restaurants/southport-grocery-and-cafe"},{"@type":"ListItem","position":6,"url":"http://www.timeout.com/chicago/bars/analogue"},{"@type":"ListItem","position":7,"url":"http://www.timeout.com/chicago/restaurants/baker-miller-bakery-millhouse"},{"@type":"ListItem","position":8,"url":"http://www.timeout.com/chicago/restaurants/jam"},{"@type":"ListItem","position":9,"url":"http://www.timeout.com/chicago/bars/pub-royale"},{"@type":"ListItem","position":10,"url":"http://www.timeout.com/chicago/restaurants/cantina-1910"}]}
#   </script>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","licenseKey":"078547f172","applicationID":"9688129","transactionName":"Y1MDNktRXkBQWkANCVoZIAFNWV9dHklVAwNrXw8GXEg=","queueTime":0,"applicationTime":1340,"atts":"TxQAQANLTU4=","errorBeacon":"bam.nr-data.net","agent":""}
#   </script>
#  </body>
# </html>

# %% [markdown]
# Inspecting the elements of the website, the restaurant names are contained in `<h3>` tags, which are children of `<div>` tags with the class `"feature-item__column"`. There are 40 such tags, two for each restaurant (one for an image and the other for text). The following code takes the restaurant names from the `<h3>` tags using `.findChild()`.
#
# Stepping down to the next child, the `<h3>` tags contain an `<a>` tag with the internal link to the Time Out page for each individual restaurant (which contains a more detailed description of the restaurant including reviews, average prices, location and transport). Using the `.findChild()` method twice, I can extract the `href` attribute for each restaurant and then follow these links to get additional information on the restaurants (such as the physical address).

# %%
# Get names of restaurants
div_list = tree.find_all('div', 'feature-item__column')
div_text = [t.findChild().text.strip() for t in div_list]
brunch_names = [x for x in div_text if x] # Removes empty elements in div_text list

# Get internal links to Time Out restaurant pages
child_text = [s.findChild().findChild().get('href') for s in div_list]
brunch_links = list(OrderedDict.fromkeys(child_text)) # Removes duplicate links, preserving order of list

# %% [markdown]
# The variable `brunch_names` is now a list of 20 restaurant names, and `brunch_links` is a list of 20 internal links. Inspecting the elements of the Time Out webpage for the first restaurant (Longman & Eagle), the physical address of the restaurant is contained within a `<td>` tag. Once again, there are multiple `<td>` tags on the page, but the address is in the same location on each page, the 3rd row of the "Details" table.

# %%
brunch_addresses = []
counter = 0

for link in brunch_links:
    counter += 1  
    url = "http://www.timeout.com" + link
    req = requests.get(url)
    html_page = req.text
    html_tree = bs4.BeautifulSoup(html_page, 'html.parser')
    address = html_tree.find_all('td')[2].text.strip()
    address = re.sub(" \n                                       ", ",", address)
    brunch_addresses.append(address)

# %% [markdown]
# Let's turn all this information so far into a Pandas DataFrame and look at it:

# %%
table = pd.DataFrame(data = zip(brunch_names, brunch_addresses, brunch_links), 
                          columns = ["Restaurant Name", "Address", "Time Out (internal) link"])
table
# Out:
#                     Restaurant Name                        Address                           Time Out (internal) link
# 0                   Longman & Eagle     2657 N Kedzie Ave, Chicago                 /chicago/restaurants/longman-eagle
# 1                         Au Cheval     800 W Randolph St, Chicago                     /chicago/restaurants/au-cheval
# 2                Cherry Circle Room     12 S Michigan Ave, Chicago            /chicago/restaurants/cherry-circle-room
# 3                    Bohemian House      11 W Illinois St, Chicago                /chicago/restaurants/bohemian-house
# 4        Southport Grocery and Café  3552 N Southport Ave, Chicago    /chicago/restaurants/southport-grocery-and-cafe
# 5                          Analogue  2523 N Milwaukee Ave, Chicago                             /chicago/bars/analogue
# 6   Baker Miller Bakery & Millhouse    4610 N Western Ave, Chicago  /chicago/restaurants/baker-miller-bakery-millh...
# 7                               Jam     3057 W Logan Blvd, Chicago                           /chicago/restaurants/jam
# 8                        Pub Royale    2049 W Division St, Chicago                           /chicago/bars/pub-royale
# 9                      Cantina 1910       5025 N Clark St, Chicago                  /chicago/restaurants/cantina-1910
# 10              Dove's Luncheonette      1545 N Damen Ave, Chicago            /chicago/restaurants/doves-luncheonette
# 11                              A10        1462 E 53rd St, Chicago                           /chicago/restaurants/a10
# 12                        Lula Cafe    2537 N Kedzie Blvd, Chicago                     /chicago/restaurants/lula-cafe
# 13                      The Bristol      2152 N Damen Ave, Chicago                   /chicago/restaurants/the-bristol
# 14                     The Publican   837 W Fulton Market, Chicago                  /chicago/restaurants/the-publican
# 15                        Big Jones       5347 N Clark St, Chicago                     /chicago/restaurants/big-jones
# 16                    Owen & Engine    2700 N Western Ave, Chicago                   /chicago/restaurants/owen-engine
# 17                          Beatrix        519 N Clark St, Chicago                       /chicago/restaurants/beatrix
# 18                         Scofflaw   3201 W Armitage Ave, Chicago                             /chicago/bars/scofflaw
# 19                          de Quay    2470 N Lincoln Ave, Chicago                       /chicago/restaurants/de-quay

# %% [markdown]
# Let's say I am at the Tribune Tower. Now I want to calculate the birds eye distance between me and each of these restaurants. So I convert the physical addresses into lattitude and longitude co-ordinates in preparation for calculating the distance between these points.

# %%
# Geocoding assistance from:
# http://stackoverflow.com/questions/22342097/is-it-possible-to-create-a-google-map-from-python
coordinates = []

for address in brunch_addresses:
    result = Geocoder.geocode(address)
    coordinates.append(result[0].coordinates)
    time.sleep(1) # slow number of requests to prevent OVER_QUERY_LIMIT error
    
# Let's say I am at the Tribune Tower
tribune = '435 N Michigan Ave, Chicago'
result = Geocoder.geocode(tribune)
tribune_coords = result[0].coordinates

# %% [markdown]
# To calculate the distance between the Tribune Tower and each of the 20 restaurants, I am going to use the Haversine Formula, which calculates the great-circle distance between two points on a sphere. While the curvature of the Earth probably doesn't have a large impact on the distances we are talking here, Michael Dunn on [Stack Overflow](http://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points) has already created a function to calculate these distances, so let's use it.

# %%
# Haversine function from Stack Overflow:
# http://stackoverflow.com/questions/4913349/haversine-formula-in-python-bearing-and-distance-between-two-gps-points

def haversine(lon1, lat1, lon2, lat2):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * asin(sqrt(a))
    # Radius of earth in miles.
    miles = 3956 * c  
    return miles

# Calculate distances between Tribune Tower and the 20 restaurants
distances = []

for lat, lon in coordinates:
    distances.append(haversine(tribune_coords[1], tribune_coords[0], lon, lat))

table['Distance from Tribune (miles)'] = pd.DataFrame(data = distances, columns = ["Distances"]) 
table
# Out:
#                     Restaurant Name                        Address                           Time Out (internal) link  Distance from Tribune (miles)
# 0                   Longman & Eagle     2657 N Kedzie Ave, Chicago                 /chicago/restaurants/longman-eagle                       5.103849
# 1                         Au Cheval     800 W Randolph St, Chicago                     /chicago/restaurants/au-cheval                       1.312113
# 2                Cherry Circle Room     12 S Michigan Ave, Chicago            /chicago/restaurants/cherry-circle-room                       0.603255
# 3                    Bohemian House      11 W Illinois St, Chicago                /chicago/restaurants/bohemian-house                       0.268448
# 4        Southport Grocery and Café  3552 N Southport Ave, Chicago    /chicago/restaurants/southport-grocery-and-cafe                       4.430205
# 5                          Analogue  2523 N Milwaukee Ave, Chicago                             /chicago/bars/analogue                       4.876605
# 6   Baker Miller Bakery & Millhouse    4610 N Western Ave, Chicago  /chicago/restaurants/baker-miller-bakery-millh...                       6.182131
# 7                               Jam     3057 W Logan Blvd, Chicago                           /chicago/restaurants/jam                       4.928953
# 8                        Pub Royale    2049 W Division St, Chicago                           /chicago/bars/pub-royale                       2.999283
# 9                      Cantina 1910       5025 N Clark St, Chicago                  /chicago/restaurants/cantina-1910                       6.162883
# 10              Dove's Luncheonette      1545 N Damen Ave, Chicago            /chicago/restaurants/doves-luncheonette                       3.074009
# 11                              A10        1462 E 53rd St, Chicago                           /chicago/restaurants/a10                       6.485957
# 12                        Lula Cafe    2537 N Kedzie Blvd, Chicago                     /chicago/restaurants/lula-cafe                       5.009861
# 13                      The Bristol      2152 N Damen Ave, Chicago                   /chicago/restaurants/the-bristol                       3.522286
# 14                     The Publican   837 W Fulton Market, Chicago                  /chicago/restaurants/the-publican                       1.350345
# 15                        Big Jones       5347 N Clark St, Chicago                     /chicago/restaurants/big-jones                       6.568599
# 16                    Owen & Engine    2700 N Western Ave, Chicago                   /chicago/restaurants/owen-engine                       4.335655
# 17                          Beatrix        519 N Clark St, Chicago                       /chicago/restaurants/beatrix                       0.395867
# 18                         Scofflaw   3201 W Armitage Ave, Chicago                             /chicago/bars/scofflaw                       4.696626
# 19                          de Quay    2470 N Lincoln Ave, Chicago                       /chicago/restaurants/de-quay                       2.898696

# %% [markdown]
# Sanity checking these calculated distances, I picked two restaurants to check:
#
# - The haversine function calculated the closest brunch location is Bohemian House, at approximately 0.3 miles from the Tribune Tower. Using Google Maps, the approximate walking distance between these two locations is 0.4 miles, which seems reasonable.
# - Checking another, Au Cheval is calculated at 1.3 miles from the Tribune Tower. Google Maps puts the shortest walking distance at 1.5 miles, which is also reasonable, given the Haversine formula calculates direct distances between two GPS points, while Google approximates walking distance along sidewalks.
#
# Let's visualise this! The code below puts these restaurant locations on a map.

# %%
map_data = pd.DataFrame(data = coordinates, columns = ["Latitude", "Longitude"]) 
map_data['Restaurant Name'] = table['Restaurant Name']

map_osm = folium.Map(location = [tribune_coords[0], tribune_coords[1]], 
                    tiles = 'Stamen Terrain',
                    zoom_start = 11)
for row in range(20):
    folium.Marker([map_data.ix[row, 'Latitude'], map_data.ix[row, 'Longitude']], 
                  popup = map_data.ix[row, 'Restaurant Name']).add_to(map_osm)
folium.Marker([tribune_coords[0], tribune_coords[1]], popup = 'Tribune Tower', 
              icon = folium.Icon(color = 'red', icon = 'question-sign')).add_to(map_osm)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %% [markdown]
# Great!
#
# Now I want to send myself an email that suggests a new brunch spot. But first, I want to eliminate those places I've already been:

# %%
# Places I've been to from the brunch list:
brunch_done = ['Analogue', 'Au Cheval', 'Beatrix']

# Place from the brunch list I haven't been:
brunch_not_done = [i for i in table['Restaurant Name'] if i not in brunch_done]

brunch_df = table.loc[table['Restaurant Name'].isin(brunch_not_done)]
brunch_df
# Out:
#                     Restaurant Name                        Address                           Time Out (internal) link  Distance from Tribune (miles)
# 0                   Longman & Eagle     2657 N Kedzie Ave, Chicago                 /chicago/restaurants/longman-eagle                       5.103849
# 2                Cherry Circle Room     12 S Michigan Ave, Chicago            /chicago/restaurants/cherry-circle-room                       0.603255
# 3                    Bohemian House      11 W Illinois St, Chicago                /chicago/restaurants/bohemian-house                       0.268448
# 4        Southport Grocery and Café  3552 N Southport Ave, Chicago    /chicago/restaurants/southport-grocery-and-cafe                       4.430205
# 6   Baker Miller Bakery & Millhouse    4610 N Western Ave, Chicago  /chicago/restaurants/baker-miller-bakery-millh...                       6.182131
# 7                               Jam     3057 W Logan Blvd, Chicago                           /chicago/restaurants/jam                       4.928953
# 8                        Pub Royale    2049 W Division St, Chicago                           /chicago/bars/pub-royale                       2.999283
# 9                      Cantina 1910       5025 N Clark St, Chicago                  /chicago/restaurants/cantina-1910                       6.162883
# 10              Dove's Luncheonette      1545 N Damen Ave, Chicago            /chicago/restaurants/doves-luncheonette                       3.074009
# 11                              A10        1462 E 53rd St, Chicago                           /chicago/restaurants/a10                       6.485957
# 12                        Lula Cafe    2537 N Kedzie Blvd, Chicago                     /chicago/restaurants/lula-cafe                       5.009861
# 13                      The Bristol      2152 N Damen Ave, Chicago                   /chicago/restaurants/the-bristol                       3.522286
# 14                     The Publican   837 W Fulton Market, Chicago                  /chicago/restaurants/the-publican                       1.350345
# 15                        Big Jones       5347 N Clark St, Chicago                     /chicago/restaurants/big-jones                       6.568599
# 16                    Owen & Engine    2700 N Western Ave, Chicago                   /chicago/restaurants/owen-engine                       4.335655
# 18                         Scofflaw   3201 W Armitage Ave, Chicago                             /chicago/bars/scofflaw                       4.696626
# 19                          de Quay    2470 N Lincoln Ave, Chicago                       /chicago/restaurants/de-quay                       2.898696

# %% [markdown]
# Okay, from this list of brunch places I haven't been to yet, I want my py script to pick the closest restaurant and suggest it to me.

# %%
brunch_df[brunch_df['Distance from Tribune (miles)'] == min(brunch_df['Distance from Tribune (miles)'])]

brunch_index = brunch_df['Distance from Tribune (miles)'].idxmin(1)
closest_new_brunch = brunch_names[brunch_index]

# Create list of Time Out's short descriptions of each restaurant
brunch_desc = []

for t in tree.find_all('div', "column"):
    desc = t.findChild().text.encode('utf-8')
    # I feel like there is a better way to deal with the unicode below, more research needed
    desc = desc.replace("\xc2\xa0", " ").replace("\xe2\x80\x94", "-").replace(
                        "\xe2\x80\x99", "'").replace("\xcc\x81", "")
    brunch_desc.append(desc)

# Now, let's make a mail message we can read:
# Code adapted from https://github.com/kjam/python-web-scraping-tutorial/blob/master/scraper.py
message = 'Hey Jill,\n\n'
message += 'You should go to brunch this weekend! \n'
message += "The closest place you haven't been to already is %s at %s. " % (
            closest_new_brunch, brunch_addresses[brunch_index])
message += 'This is what Time Out Chicago says: \n\n'
message += '==============================\n'
message += '%s \n' % (brunch_desc[brunch_index])
message += '==============================\n\n'
message += 'Check out this link for more details: www.timeout.com%s. ' % (brunch_links[brunch_index])
message += '\n\nFrom,\n Your Py Script'

print message
# Out:
# Hey Jill,
#
# You should go to brunch this weekend!
# The closest place you haven't been to already is Bohemian House at 11 W Illinois St, Chicago. This is what Time Out Chicago says:
#
# ==============================
# The best doughnuts in the city are hiding in an unlikely place: a modern Central European restaurant in River North. Here, chef Jimmy Papadopoulos and crew turn out warm orbs of fried dough tossed with sugar and served with Bavarian cream and raspberry jam. The rest of the menu is just as stellar: Tender nuggets of beef tongue mingle with potatoes and cabbage in the hash, while the giant open-faced schnitzel sandwich could easily serve two.
# ==============================
#
# Check out this link for more details: www.timeout.com/chicago/restaurants/bohemian-house.
#
# From,
#  Your Py Script

# %% [markdown]
# Now doesn't that sound tasty?
